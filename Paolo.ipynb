# %%
import fitz
import pandas as pd
import nltk
import re
from nltk.tokenize import sent_tokenize
from langdetect import detect
import langid
nltk.download('cess_esp')
from nltk.corpus import cess_esp
from nltk.tokenize import word_tokenize
import os

spanish_words = set(word for word in cess_esp.words())
# Out:
# [nltk_data] Downloading package cess_esp to
# [nltk_data]     C:\Users\perez\AppData\Roaming\nltk_data...
# [nltk_data]   Package cess_esp is already up-to-date!

# %%
def get_text_from_pdf(name):
    doc = fitz.open(f'data/{name}.pdf')
    full_text=""

    for page in doc.pages():
        this_page_text=page.get_text("text", sort=True).replace("\n", " ")
        this_page_text=re.sub(r'\d+', '', this_page_text)
        full_text+=this_page_text+" "
    
    return full_text

def get_all_text_from_pdf(name):
    doc = fitz.open(f'data/{name}.pdf')
    full_text=" ".join([page.get_text("text", sort=True).replace("\n", " ") for page in doc])
    full_text=re.sub(r'\d+', '', full_text)
    return full_text

# %%
def spanish_filter(full_text):
    sentences = sent_tokenize(full_text)
    non_spanish_sentences = []

    for sentence in sentences:
        try:
            languages=[]
            languages.append(detect(sentence))
            languages.append(langid.classify(sentence)[0])
            if not any(lang in languages for lang in ["es", "it", "ca", "pt"]):
                non_spanish_sentences.append(sentence)
        except:
            pass

    sentences = non_spanish_sentences
    

    return sentences

def spanish_sentences_filter(sentence):
    try:
        languages=[]
        languages.append(detect(sentence))
        languages.append(langid.classify(sentence)[0])
        if not any(lang in languages for lang in ["es", "it", "ca", "pt"]):
            return True
    except:
        pass

    return False

# %%
quechua_alphabet = ['a', 'aa', 'ch', 'chh', 'ch\'', 'ts', 'tr', 'h', 'i', 'ii', 'k', 'kh', 'k\'', 'l', 'll', 'm', 'n', 'ñ', 'p', 'ph', 'p\'', 'q', 'qh', 'q\'', 'r', 's', 'sh', 't', 'th', 't\'', 'u', 'uu', 'w', 'y']

def grafemas_no_en_alfabet(words):
    for word in words:
        for i, letter in enumerate(word):
            #Continue  if letter is not a letter
            if not letter.isalpha():
                continue
            if letter.lower() not in quechua_alphabet:
                #Chequear siguiente letra
                if i+1 >= len(word):
                    return False
                letter = letter + word[i+1]
                if letter.lower() not in quechua_alphabet:
                    if i+2 >= len(word):
                        return False
                    #Chequear siguiente letra
                    letter = letter + word[i+2]
                    if letter.lower() not in quechua_alphabet:
                        return False
    return True

#No funciona bien esta función, porque el detector de lenguaje no es muy bueno para palabras 
def oraciones_mucho_espaniol(words):
    spanish_words = 0
    for word in words:
        try:
            if detect(word) == 'es':
                spanish_words += 1
        except:
            pass
    return spanish_words/len(words) > 0.5

def oracion_mucho_espaniol_v2(words):
    palabras_encontradas = 0
    #Usar un diccionario de palabras en español
    for word in words:
        if word.lower() in spanish_words:
            palabras_encontradas += 1

    return palabras_encontradas/len(words) < 0.25


def oraciones_muy_cortas(words, min_length=3):
    return len(words) > min_length

def oraciones_muy_repititivas(words, threshold=0.4):
    unique_words = set(words)
    ratio = len(unique_words) / len(words)
    return ratio >= threshold

def palabras_muy_largas(words, threshold=40):
    for word in words:
        if len(word) > threshold:
            return False
    return True

def split_tokens(sentence):
    if re.search(r"(\b\w{1,2}\b\s){3,}", sentence):
        return False
    return True

def oraciones_con_matematica(sentence):
    if re.search(r"[\d+\-*/]+", sentence):
        return False
    return True

# %%
def rule_based_heuristic(sentence):
    words = word_tokenize(sentence)
    aux_solo_palabras = [word for word in words if word.isalpha()]
    
    valid = oraciones_muy_cortas(aux_solo_palabras) 
    valid = valid and oraciones_muy_repititivas(aux_solo_palabras)
    valid = valid and palabras_muy_largas(words)
    valid = valid and split_tokens(sentence)
    valid = valid and oraciones_con_matematica(sentence)
    valid = valid and oracion_mucho_espaniol_v2(aux_solo_palabras)

    return valid

# %%
def pipeline(documents):
    corpus=pd.DataFrame(columns=["document", "sentence"])
    for document in documents:
        text=get_text_from_pdf(document)
        sentences=sent_tokenize(text)
        #Oraciones antes de filtrar
        print("Oraciones antes de filtrar en documento ", document, ": ", len(sentences))
        filtered_sentences=[]
        for sentence in sentences:
            if rule_based_heuristic(sentence) and spanish_sentences_filter(sentence):
                filtered_sentences.append(sentence)
        
        df=pd.DataFrame(filtered_sentences, columns=["sentence"])
        df["document"]=document
        #Quitar duplicados
        df.drop_duplicates(subset="sentence", inplace=True)
        print("Oraciones después de filtrar en documento ", document, ": ", len(df))
        corpus=pd.concat([corpus, df], ignore_index=True)
    print("Total de oraciones: ", len(corpus))
    corpus.drop_duplicates(subset="sentence", inplace=True)
    print("Total de oraciones únicas: ", len(corpus))
    return corpus

# %%
path = "data/"

documents = []

# Get all the PDF documents NAMES from the path
for file in os.listdir(path):
    if file.endswith(".pdf"):
        documents.append(file[:-4])

print(documents)

df_corpus=pipeline(documents)
df_corpus.head()
# Out:
# ['4 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 4° de Secundaria - Quechua Chanka', '5 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 5° Secundaria - Quechua Chanka', 'Anqarakunapa kawsakuyninmanta. Literatura 2 - 4° Primaria - Quechua Chanka', 'Antuku hampatuwan. Historias y relatos 2- Inicial - Quechua Chanka', 'Ayllunchikpa Willakuyninkuna. Historias y relatos 1 - Inicial - Quechua Chanka', 'Añañaw. Willakuy 4 - Quechua Chanka', 'cuentos_3-3-1 - Quechua Collao', 'Hanaq pachaman qispiq atuqman. Willakuy 9 - Quechua Chanka', 'Kicharisqa ñawiywanmi ñuqa uyarini. Willakuy 2 - Quechua Chanka', 'Llaqtanchikpa kawsayninkuna - Chanka Saberes de los pueblos 1 - 1° Secundaria - Quechua chanka', 'Llaqtaypa Kawsayninkuna. Saberes de los pueblos - 4° Primaria - Quechua Chanka', 'Maychi hampimanta. Historias y relatos 3- Inicial - Quechua Chanka', 'Muki. Willakuy 11 - Quechua Chanka', 'Pawqar llikllachay- Willakuy 3 - Quechua Chanka', 'Poemas en Quechua de Cusco - Quechua Collao', 'Qintiwan Amaru. Historias y relatos 4 - Inicial - Quechua Chanka', 'Ñawichana Maytu 1 Quechua - Chanka. Texto de Comunicación del 1° Primaria - Quechua Chanka', 'Ñawinchana Maytu 2 Quechua - Chanka. Texto de Comunicación del 2° Primaria - Quechua Chanka', 'Ñawinchana Maytu 3 Quechua - Chanka. Texto de Comunicación del 3 ° Primaria - Quechua Chanka', 'Ñawinchanapaq munay qillqasqakuna 2019 - Quechua Chanka']
# Oraciones antes de filtrar en documento  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 4° de Secundaria - Quechua Chanka :  1415
# Oraciones después de filtrar en documento  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 4° de Secundaria - Quechua Chanka :  757
# Oraciones antes de filtrar en documento  5 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 5° Secundaria - Quechua Chanka :  1623
# Oraciones después de filtrar en documento  5 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 5° Secundaria - Quechua Chanka :  870
# Oraciones antes de filtrar en documento  Anqarakunapa kawsakuyninmanta. Literatura 2 - 4° Primaria - Quechua Chanka :  1089
# Oraciones después de filtrar en documento  Anqarakunapa kawsakuyninmanta. Literatura 2 - 4° Primaria - Quechua Chanka :  463
# Oraciones antes de filtrar en documento  Antuku hampatuwan. Historias y relatos 2- Inicial - Quechua Chanka :  35
# Oraciones después de filtrar en documento  Antuku hampatuwan. Historias y relatos 2- Inicial - Quechua Chanka :  19
# Oraciones antes de filtrar en documento  Ayllunchikpa Willakuyninkuna. Historias y relatos 1 - Inicial - Quechua Chanka :  28
# Oraciones después de filtrar en documento  Ayllunchikpa Willakuyninkuna. Historias y relatos 1 - Inicial - Quechua Chanka :  21
# Oraciones antes de filtrar en documento  Añañaw. Willakuy 4 - Quechua Chanka :  2
# Oraciones después de filtrar en documento  Añañaw. Willakuy 4 - Quechua Chanka :  0
# Oraciones antes de filtrar en documento  cuentos_3-3-1 - Quechua Collao :  99
# Oraciones después de filtrar en documento  cuentos_3-3-1 - Quechua Collao :  40
# Oraciones antes de filtrar en documento  Hanaq pachaman qispiq atuqman. Willakuy 9 - Quechua Chanka :  51
# Oraciones después de filtrar en documento  Hanaq pachaman qispiq atuqman. Willakuy 9 - Quechua Chanka :  14
# Oraciones antes de filtrar en documento  Kicharisqa ñawiywanmi ñuqa uyarini. Willakuy 2 - Quechua Chanka :  7
# Oraciones después de filtrar en documento  Kicharisqa ñawiywanmi ñuqa uyarini. Willakuy 2 - Quechua Chanka :  3
# Oraciones antes de filtrar en documento  Llaqtanchikpa kawsayninkuna - Chanka Saberes de los pueblos 1 - 1° Secundaria - Quechua chanka :  688
# Oraciones después de filtrar en documento  Llaqtanchikpa kawsayninkuna - Chanka Saberes de los pueblos 1 - 1° Secundaria - Quechua chanka :  583
# Oraciones antes de filtrar en documento  Llaqtaypa Kawsayninkuna. Saberes de los pueblos - 4° Primaria - Quechua Chanka :  63
# Oraciones después de filtrar en documento  Llaqtaypa Kawsayninkuna. Saberes de los pueblos - 4° Primaria - Quechua Chanka :  29
# Oraciones antes de filtrar en documento  Maychi hampimanta. Historias y relatos 3- Inicial - Quechua Chanka :  27
# Oraciones después de filtrar en documento  Maychi hampimanta. Historias y relatos 3- Inicial - Quechua Chanka :  20
# Oraciones antes de filtrar en documento  Muki. Willakuy 11 - Quechua Chanka :  54
# Oraciones después de filtrar en documento  Muki. Willakuy 11 - Quechua Chanka :  29
# Oraciones antes de filtrar en documento  Pawqar llikllachay- Willakuy 3 - Quechua Chanka :  15
# Oraciones después de filtrar en documento  Pawqar llikllachay- Willakuy 3 - Quechua Chanka :  10
# Oraciones antes de filtrar en documento  Poemas en Quechua de Cusco - Quechua Collao :  9
# Oraciones después de filtrar en documento  Poemas en Quechua de Cusco - Quechua Collao :  3
# Oraciones antes de filtrar en documento  Qintiwan Amaru. Historias y relatos 4 - Inicial - Quechua Chanka :  51
# Oraciones después de filtrar en documento  Qintiwan Amaru. Historias y relatos 4 - Inicial - Quechua Chanka :  21
# Oraciones antes de filtrar en documento  Ñawichana Maytu 1 Quechua - Chanka. Texto de Comunicación del 1° Primaria - Quechua Chanka :  756
# Oraciones después de filtrar en documento  Ñawichana Maytu 1 Quechua - Chanka. Texto de Comunicación del 1° Primaria - Quechua Chanka :  434
# Oraciones antes de filtrar en documento  Ñawinchana Maytu 2 Quechua - Chanka. Texto de Comunicación del 2° Primaria - Quechua Chanka :  717
# Oraciones después de filtrar en documento  Ñawinchana Maytu 2 Quechua - Chanka. Texto de Comunicación del 2° Primaria - Quechua Chanka :  317
# Oraciones antes de filtrar en documento  Ñawinchana Maytu 3 Quechua - Chanka. Texto de Comunicación del 3 ° Primaria - Quechua Chanka :  851
# Oraciones después de filtrar en documento  Ñawinchana Maytu 3 Quechua - Chanka. Texto de Comunicación del 3 ° Primaria - Quechua Chanka :  502
# Oraciones antes de filtrar en documento  Ñawinchanapaq munay qillqasqakuna 2019 - Quechua Chanka :  501
# Oraciones después de filtrar en documento  Ñawinchanapaq munay qillqasqakuna 2019 - Quechua Chanka :  376
# Total de oraciones:  4511
# Total de oraciones únicas:  4473
#                                             document  \
# 0  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 1  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 2  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 3  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 4  4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
#
#                                             sentence
# 0  Sapa taqam ñawpa llaqtapa huk llamkananmanta r...
# 1  Hinaspapas taqapi ruraykunaqa llaqta llamkayni...
# 2  Kaymanhinam sasachakuy  imayna chinkachiypi ya...
# 3  Kayna:  huk taqam papa tarpuymanta riman, papa...
# 4  Chaymanhinam qamta munachisunki, imaynataq pap...

# %%
df_corpus.loc[df_corpus["sentence"].apply(lambda x: len(x))<40]
# Out:
#                                                document  \
# 19    4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 39    4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 49    4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 51    4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# 74    4 Rimana - Qillqasqa maytu - Qichwa, Chanka. T...
# ...                                                 ...
# 4412  Ñawinchanapaq munay qillqasqakuna 2019 - Quech...
# 4437  Ñawinchanapaq munay qillqasqakuna 2019 - Quech...
# 4440  Ñawinchanapaq munay qillqasqakuna 2019 - Quech...
# 4442  Ñawinchanapaq munay qillqasqakuna 2019 - Quech...
# 4456  Ñawinchanapaq munay qillqasqakuna 2019 - Quech...
#
#                                    sentence
# 19        Sara musqukuyqa hatun  kusikuymi.
# 39    Nispas kumun masinkunata rimapayasqa.
# 49              Mitu Huk rikchaq qillqasqa.
# 51    Runakuna yachankuchu mayman risqanta.
# 74        ¿Pitaq takiq pisqu kanman karqan?
# ...                                     ...
# 4412          Manas runapas uywapas kanchu.
# 4437  Kunanqa  wachu  wachutaña  qillqanki.
# 4440  Kay qillqasqaykiqa chuyachañam kanan.
# 4442    Kunanñataq, huk rapiman qillqarquy.
# 4456          Arí, niptinsi, kuska risqaku.
#
# [192 rows x 2 columns]

# %%
df_corpus.to_csv("data/corpus/avancePaolo.csv", index=False)

# %%
# documents name formatted:
for document in documents:
    print(f'- {document}')
# Out:
# - 4 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 4° de Secundaria - Quechua Chanka
# - 5 Rimana - Qillqasqa maytu - Qichwa, Chanka. Texto de Comunicación del 5° Secundaria - Quechua Chanka
# - Anqarakunapa kawsakuyninmanta. Literatura 2 - 4° Primaria - Quechua Chanka
# - Antuku hampatuwan. Historias y relatos 2- Inicial - Quechua Chanka
# - Ayllunchikpa Willakuyninkuna. Historias y relatos 1 - Inicial - Quechua Chanka
# - Añañaw. Willakuy 4 - Quechua Chanka
# - cuentos_3-3-1 - Quechua Collao
# - Hanaq pachaman qispiq atuqman. Willakuy 9 - Quechua Chanka
# - Kicharisqa ñawiywanmi ñuqa uyarini. Willakuy 2 - Quechua Chanka
# - Llaqtanchikpa kawsayninkuna - Chanka Saberes de los pueblos 1 - 1° Secundaria - Quechua chanka
# - Llaqtaypa Kawsayninkuna. Saberes de los pueblos - 4° Primaria - Quechua Chanka
# - Maychi hampimanta. Historias y relatos 3- Inicial - Quechua Chanka
# - Muki. Willakuy 11 - Quechua Chanka
# - Pawqar llikllachay- Willakuy 3 - Quechua Chanka
# - Poemas en Quechua de Cusco - Quechua Collao
# - Qintiwan Amaru. Historias y relatos 4 - Inicial - Quechua Chanka
# - Ñawichana Maytu 1 Quechua - Chanka. Texto de Comunicación del 1° Primaria - Quechua Chanka
# - Ñawinchana Maytu 2 Quechua - Chanka. Texto de Comunicación del 2° Primaria - Quechua Chanka
# - Ñawinchana Maytu 3 Quechua - Chanka. Texto de Comunicación del 3 ° Primaria - Quechua Chanka
# - Ñawinchanapaq munay qillqasqakuna 2019 - Quechua Chanka
